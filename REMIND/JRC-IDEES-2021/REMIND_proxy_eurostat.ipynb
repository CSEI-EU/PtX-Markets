# %%
import pandas as pd
import geopandas as gpd
import os
from osgeo import ogr
import numpy as np

# %% [markdown]
# #### Global treatment of Eurostat and REMIND
#
# ##### Global steps :
# - Use the saved files from Eurostat
# - Distribute shares for countries to the total value
# - Save new final output file with only relevant data

# %%
os.chdir(r"C:\Users\mar.eco\OneDrive - CBS - Copenhagen Business School\Desktop\PtX-Markets\REMIND")

# %%
transport_data = pd.read_csv("REMIND_Transport_Output.mif", sep=';')

# %%
transport_data = transport_data.drop(columns={"Model", "Scenario","2055", "2060", "2070", "2080", "2090", "2100", "2110", "2130", "2150"})

# %%
transport_data.Region.unique()
Variable = transport_data['Variable'].str.split('|', expand=True)

# %%
transport_EU = transport_data.query("Region == 'EU27'")

# %%
def split_variable(df):
    variables = df['Variable'].str.split('|', expand=True)
    num_cols =  variables.shape[1]
    new_column_names = [f'Variable_{i}' for i in range(num_cols)]
    df[new_column_names] = variables
    return(df)

# %%
transport_EU = split_variable(transport_EU)
# Out:
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables
# C:\Users\mar.eco\AppData\Local\Temp\ipykernel_14108\3017919102.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[new_column_names] = variables

# %%
final_energy = transport_EU[(transport_EU["Variable_0"] == "FE") & (transport_EU["Variable_1"] == "Transport")]

# %%
final_energy
# Out:
#        Region                                           Variable   Unit  \
# 82801    EU27  FE|Transport|Bunkers|Freight|International Shi...  EJ/yr
# 82826    EU27  FE|Transport|Bunkers|Freight|International Shi...  EJ/yr
# 82851    EU27  FE|Transport|Bunkers|Freight|International Shi...  EJ/yr
# 82876    EU27  FE|Transport|Bunkers|Pass|International Aviati...  EJ/yr
# 82901    EU27  FE|Transport|Bunkers|Pass|International Aviati...  EJ/yr
# ...       ...                                                ...    ...
# 135672   EU27                FE|Transport|Pass|Aviation|Hydrogen  EJ/yr
# 135675   EU27                 FE|Transport|Pass|Aviation|Liquids  EJ/yr
# 135799   EU27         FE|Transport|Pass|Aviation|Liquids||Fossil  EJ/yr
# 135802   EU27       FE|Transport|Pass|Aviation|Liquids||Hydrogen  EJ/yr
# 135805   EU27        FE|Transport|Pass|Aviation|Liquids||Biomass  EJ/yr
#
#             2005      2010      2015      2020          2025          2030  \
# 82801   0.009081  0.016569  0.026675  0.086255  1.752095e-01  1.756969e-01
# 82826   1.928230  1.902167  1.887295  1.828646  1.735520e+00  1.720969e+00
# 82851   0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000e+00
# 82876   0.013064  0.021189  0.028266  0.066779  1.134717e-01  1.123739e-01
# 82901   1.248860  1.286443  1.216144  1.140997  1.073285e+00  1.046982e+00
# ...          ...       ...       ...       ...           ...           ...
# 135672  0.000000  0.000000  0.000000  0.000000  1.968411e-08  4.825360e-08
# 135675  1.535866  1.576815  1.370199  1.343418  1.328005e+00  1.338677e+00
# 135799  1.520136  1.551127  1.338982  1.267384  1.201112e+00  1.206651e+00
# 135802  0.000000  0.000000  0.000000  0.000000  0.000000e+00  0.000000e+00
# 135805  0.015730  0.025688  0.031217  0.076034  1.268925e-01  1.320265e-01
#
#             2035  ...  Variable_3              Variable_4  Variable_5  \
# 82801   0.182370  ...     Freight  International Shipping     Liquids
# 82826   1.700257  ...     Freight  International Shipping     Liquids
# 82851   0.000000  ...     Freight  International Shipping     Liquids
# 82876   0.114467  ...        Pass  International Aviation     Liquids
# 82901   1.011112  ...        Pass  International Aviation     Liquids
# ...          ...  ...         ...                     ...         ...
# 135672  0.000001  ...    Aviation                Hydrogen        None
# 135675  1.326241  ...    Aviation                 Liquids        None
# 135799  1.183565  ...    Aviation                 Liquids
# 135802  0.000000  ...    Aviation                 Liquids
# 135805  0.142675  ...    Aviation                 Liquids
#
#         Variable_6 Variable_7 Variable_8 Variable_9 Variable_10 Variable_11  \
# 82801      Biomass       None       None       None        None        None
# 82826       Fossil       None       None       None        None        None
# 82851     Hydrogen       None       None       None        None        None
# 82876      Biomass       None       None       None        None        None
# 82901       Fossil       None       None       None        None        None
# ...            ...        ...        ...        ...         ...         ...
# 135672        None       None       None       None        None        None
# 135675        None       None       None       None        None        None
# 135799      Fossil       None       None       None        None        None
# 135802    Hydrogen       None       None       None        None        None
# 135805     Biomass       None       None       None        None        None
#
#        Variable_12
# 82801         None
# 82826         None
# 82851         None
# 82876         None
# 82901         None
# ...            ...
# 135672        None
# 135675        None
# 135799        None
# 135802        None
# 135805        None
#
# [348 rows x 27 columns]

# %%
def filter_exact_path(df, path):
    variables_split = df['Variable'].str.split('|', expand=True)
    expected_depth = len(path.split('|'))
    
    # Replace None/NaN with empty strings to avoid errors
    cleaned = variables_split.iloc[:, :expected_depth].fillna('')
    
    joined_path = cleaned.agg('|'.join, axis=1)
    actual_depth = variables_split.notna().sum(axis=1)

    mask = (joined_path == path) & (actual_depth == expected_depth)
    return df[mask]

# %%
categories = [
    "FE|Transport|Freight|Road|Heavy",
    "FE|Transport|Freight|Road|Light",
    "FE|Transport|Pass|Road|Bus",
    "FE|Transport|Pass|Road|LDV|Four Wheelers",
    "FE|Transport|Pass|Road|LDV|Two Wheelers",
    "FE|Transport|Pass|Domestic Aviation",
    "FE|Transport|Pass|Aviation",
    "FE|Transport|Pass|Rail",
    "FE|Transport|Freight|Rail"
]

# %%
categories_fuel_4w = [
    "FE|Transport|Pass|Road|LDV|Four Wheelers|Electricity",
    "FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen",
    "FE|Transport|Pass|Road|LDV|Four Wheelers|Gases",
    "FE|Transport|Pass|Road|LDV|Four Wheelers|Liquids",
]

# %%
filtered_data = {}
for category in categories:
    filtered_data[category] = filter_exact_path(final_energy, category)

# %%
filtered_data_4w = {}
for category in categories_fuel_4w:
    filtered_data_4w[category] = filter_exact_path(final_energy, category)

# %%
filtered_data['FE|Transport|Pass|Road|LDV|Four Wheelers']
# Out:
#        Region                                  Variable   Unit      2005  \
# 106996   EU27  FE|Transport|Pass|Road|LDV|Four Wheelers  EJ/yr  6.402265
#
#            2010      2015      2020      2025      2030      2035  ...  \
# 106996  6.78462  6.755867  6.756423  6.178979  5.292917  3.971894  ...
#
#         Variable_3  Variable_4     Variable_5  Variable_6 Variable_7  \
# 106996        Road         LDV  Four Wheelers        None       None
#
#        Variable_8 Variable_9 Variable_10 Variable_11 Variable_12
# 106996       None       None        None        None        None
#
# [1 rows x 27 columns]

# %%
filtered_data_4w['FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen']
# Out:
#        Region                                           Variable   Unit  \
# 119211   EU27  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen  EJ/yr
#
#             2005      2010      2015      2020      2025      2030      2035  \
# 119211  0.018026  0.018662  0.016835  0.014803  0.018083  0.024181  0.061484
#
#         ...  Variable_3  Variable_4     Variable_5  Variable_6 Variable_7  \
# 119211  ...        Road         LDV  Four Wheelers    Hydrogen       None
#
#        Variable_8 Variable_9 Variable_10 Variable_11 Variable_12
# 119211       None       None        None        None        None
#
# [1 rows x 27 columns]

# %% [markdown]
# ##### Import Eurostat files to use as proxy
#
# The Eurostat files have share for every EU27 countries as well as the total value of EU27.
# The objective is to create a new final dataframe that has :
# - Transport category (12 total categories)
# - Given EU27 value of REMIND for each year
# - Share of the choesen Eurostat year for each country
# - Values for each country of EU27 and each year

# %%
file_names = ["estat_road_go_ta_mplw_heavy.tsv.gz", "estat_road_go_ta_mplw_light.tsv.gz", 
             "estat_tran_r_vehst.tsv.gz", "estat_road_eqs_carmot.tsv.gz", "estat_road_eqs_two_wheelers.tsv.gz",
              "estat_avia_panc.tsv.gz", "estat_avia_international.tsv.gz", 
              "estat_ttr00015.tsv.gz", "estat_ttr00006.tsv.gz"]

# %%
file_names_4w = ["estat_road_eqs_carmot.tsv.gz", "estat_road_eqs_carmot.tsv.gz", 
             "estat_road_eqs_carmot.tsv.gz", "estat_road_eqs_carmot.tsv.gz"]

# %%
base_path = r"C:\Users\mar.eco\OneDrive - CBS - Copenhagen Business School\Desktop\PtX-Markets\REMIND\Data\Final"

# %%
category_file_map = dict(zip(categories, file_names))
category_file_map
# Out:
# {'FE|Transport|Freight|Road|Heavy': 'estat_road_go_ta_mplw_heavy.tsv.gz',
#  'FE|Transport|Freight|Road|Light': 'estat_road_go_ta_mplw_light.tsv.gz',
#  'FE|Transport|Pass|Road|Bus': 'estat_tran_r_vehst.tsv.gz',
#  'FE|Transport|Pass|Road|LDV|Four Wheelers': 'estat_road_eqs_carmot.tsv.gz',
#  'FE|Transport|Pass|Road|LDV|Two Wheelers': 'estat_road_eqs_two_wheelers.tsv.gz',
#  'FE|Transport|Pass|Domestic Aviation': 'estat_avia_panc.tsv.gz',
#  'FE|Transport|Pass|Aviation': 'estat_avia_international.tsv.gz',
#  'FE|Transport|Pass|Rail': 'estat_ttr00015.tsv.gz',
#  'FE|Transport|Freight|Rail': 'estat_ttr00006.tsv.gz'}

# %%
category_file_map_4w = dict(zip(categories_fuel_4w, file_names_4w))
category_file_map_4w
# Out:
# {'FE|Transport|Pass|Road|LDV|Four Wheelers|Electricity': 'estat_road_eqs_carmot.tsv.gz',
#  'FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen': 'estat_road_eqs_carmot.tsv.gz',
#  'FE|Transport|Pass|Road|LDV|Four Wheelers|Gases': 'estat_road_eqs_carmot.tsv.gz',
#  'FE|Transport|Pass|Road|LDV|Four Wheelers|Liquids': 'estat_road_eqs_carmot.tsv.gz'}

# %%
def process_value(value):
    # Check if there's exactly one dot (then it is a decimal and not thousand)
    if value.count('.') == 1:
        if len(value.split('.')[0]) > 3:
            return value.replace(".", "")  # Remove dot as thousands separator
        else:
            return value
    else:
        # If there's no dot or multiple dots, remove all dots (treat as thousands)
        return value.replace(".", "")

# %%
all_distributed = []
for category, eurostat_file in category_file_map.items():
    remind_df = filtered_data[category]
    eurostat_path = os.path.join(base_path, eurostat_file)

    remind_row = remind_df[remind_df["Region"] == "EU27"].iloc[0]
    years = [col for col in remind_row.index if col.isdigit()]
    
    remind_values = remind_row[years].astype(str).apply(process_value).astype(float)

    euro_df = pd.read_csv(eurostat_path, compression="gzip", delimiter="\t")
    euro_df.columns = euro_df.columns.str.strip()

    # Find share column = last one
    share_col = euro_df.columns[-1]
    shares = euro_df[["country_code", share_col]].copy()
    shares.columns = ["Country", "Share"]

    for year in years:
        eu_value = remind_values[year]
        shares["Value"] = shares["Share"] * eu_value
        shares["Year"] = year
        shares["Category"] = category

        all_distributed.append(shares[["Category", "Country", "Year", "Value"]])

# %%
all_distributed = []
for category, eurostat_file in category_file_map_4w.items():
    remind_df = filtered_data_4w[category]
    eurostat_path = os.path.join(base_path, eurostat_file)

    remind_row = remind_df[remind_df["Region"] == "EU27"].iloc[0]
    years = [col for col in remind_row.index if col.isdigit()]
    
    remind_values = remind_row[years].astype(str).apply(process_value).astype(float)

    euro_df = pd.read_csv(eurostat_path, compression="gzip", delimiter="\t")
    euro_df.columns = euro_df.columns.str.strip()

    # Find share column = last one
    share_col = euro_df.columns[-1]
    shares = euro_df[["country_code", share_col]].copy()
    shares.columns = ["Country", "Share"]

    for year in years:
        eu_value = remind_values[year]
        shares["Value"] = shares["Share"] * eu_value
        shares["Year"] = year
        shares["Category"] = category

        all_distributed.append(shares[["Category", "Country", "Year", "Value"]])

# %%
final_df = pd.concat(all_distributed, ignore_index=True)

# %%
final_df_4w = pd.concat(all_distributed, ignore_index=True)

# %%
pivoted_df = final_df.pivot_table(
    index=["Category", "Country"],  # rows: one per category & country
    columns="Year",                 # columns become the years
    values="Value"                  
).reset_index()

# %%
pivoted_df = final_df_4w.pivot_table(
    index=["Category", "Country"],  # rows: one per category & country
    columns="Year",                 # columns become the years
    values="Value"                  
).reset_index()

# %%
final_df[(final_df['Category'] == "FE|Transport|Freight|Rail") & (final_df['Year'] == "2020")]
# Out:
#                        Category    Country  Year     Value
# 2327  FE|Transport|Freight|Rail         AT  2020  0.006326
# 2328  FE|Transport|Freight|Rail         BE  2020  0.004406
# 2329  FE|Transport|Freight|Rail         BG  2020  0.001117
# 2330  FE|Transport|Freight|Rail         CY  2020  0.000000
# 2331  FE|Transport|Freight|Rail         CZ  2020  0.004503
# 2332  FE|Transport|Freight|Rail         DE  2020  0.036068
# 2333  FE|Transport|Freight|Rail         DK  2020  0.000754
# 2334  FE|Transport|Freight|Rail         EE  2020  0.000661
# 2335  FE|Transport|Freight|Rail         EL  2020  0.000102
# 2336  FE|Transport|Freight|Rail         EL  2020  0.000102
# 2337  FE|Transport|Freight|Rail         ES  2020  0.002998
# 2338  FE|Transport|Freight|Rail  EU27_2020  2020  0.121933
# 2339  FE|Transport|Freight|Rail         FI  2020  0.002945
# 2340  FE|Transport|Freight|Rail         FR  2020  0.010085
# 2341  FE|Transport|Freight|Rail         HR  2020  0.000737
# 2342  FE|Transport|Freight|Rail         HU  2020  0.003796
# 2343  FE|Transport|Freight|Rail         IE  2020  0.000028
# 2344  FE|Transport|Freight|Rail         IT  2020  0.006348
# 2345  FE|Transport|Freight|Rail         LT  2020  0.004381
# 2346  FE|Transport|Freight|Rail         LU  2020  0.000061
# 2347  FE|Transport|Freight|Rail         LV  2020  0.004267
# 2348  FE|Transport|Freight|Rail         MT  2020  0.000000
# 2349  FE|Transport|Freight|Rail         NL  2020  0.001900
# 2350  FE|Transport|Freight|Rail         PL  2020  0.015575
# 2351  FE|Transport|Freight|Rail         PT  2020  0.000782
# 2352  FE|Transport|Freight|Rail         RO  2020  0.003917
# 2353  FE|Transport|Freight|Rail         SE  2020  0.006207
# 2354  FE|Transport|Freight|Rail         SI  2020  0.001458
# 2355  FE|Transport|Freight|Rail         SK  2020  0.002409

# %%
final_df_4w[(final_df_4w['Category'] == "FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen") & (final_df['Year'] == "2020")]
# Out:
#                                               Category    Country  Year  \
# 364  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         AT  2020
# 365  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         BE  2020
# 366  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         BG  2020
# 367  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         CY  2020
# 368  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         CZ  2020
# 369  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         DE  2020
# 370  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         DK  2020
# 371  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         EE  2020
# 372  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         EL  2020
# 373  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         ES  2020
# 374  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen  EU27_2020  2020
# 375  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         FI  2020
# 376  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         FR  2020
# 377  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         HR  2020
# 378  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         HU  2020
# 379  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         IE  2020
# 380  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         IT  2020
# 381  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         LT  2020
# 382  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         LU  2020
# 383  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         LV  2020
# 384  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         MT  2020
# 385  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         NL  2020
# 386  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         PL  2020
# 387  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         PT  2020
# 388  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         RO  2020
# 389  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         SE  2020
# 390  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         SI  2020
# 391  FE|Transport|Pass|Road|LDV|Four Wheelers|Hydrogen         SK  2020
#
#         Value
# 364  0.000300
# 365  0.000350
# 366  0.000174
# 367  0.000036
# 368  0.000376
# 369  0.002838
# 370  0.000163
# 371  0.000050
# 372  0.000340
# 373  0.001548
# 374  0.014803
# 375  0.000215
# 376  0.002269
# 377  0.000110
# 378  0.000241
# 379  0.000139
# 380  0.002365
# 381  0.000098
# 382  0.000026
# 383  0.000045
# 384  0.000019
# 385  0.000524
# 386  0.001260
# 387  0.000338
# 388  0.000469
# 389  0.000288
# 390  0.000071
# 391  0.000153

# %%
check_sum = final_df[final_df['Category'] == "FE|Transport|Freight|Rail"].groupby("Year")["Value"].sum()
check_sum
# Out:
# Year
# 2005    0.243391
# 2010    0.236970
# 2015    0.198990
# 2020    0.243866
# 2025    0.250085
# 2030    0.250159
# 2035    0.241598
# 2040    0.240978
# 2045    0.239314
# 2050    0.237722
# Name: Value, dtype: float64

# %%
output_path = r"C:\Users\mar.eco\OneDrive - CBS - Copenhagen Business School\Desktop\PtX-Markets\REMIND\Results_REMIND_yearly.csv"
final_df.to_csv(output_path, index=False)

# %%
output_path = r"C:\Users\mar.eco\OneDrive - CBS - Copenhagen Business School\Desktop\PtX-Markets\REMIND\Results_REMIND_4w_yearly.csv"
final_df_4w.to_csv(output_path, index=False)
